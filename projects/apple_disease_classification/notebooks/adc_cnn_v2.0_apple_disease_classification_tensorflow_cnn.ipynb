# %% [markdown]
# <h3><strong>Tweede opzet CNN</strong></h3><br>
# Ik was niet helemaal tevreden met het eerste model en wilde graag ook meer code schrijven, i.p.v. copy/pasten.<br>
# Ben op zoek gegaan naar een voorbeeld en vond onderstaande. Het inladen en opdelen (train/validation) van de data, het labelen etc. gebeurt op een net andere manier als in het Tensorflow-tutorial,<br>
# prettig om zo voor de toekomst hiervoor meer mogelijkheden ter beschikking te hebben.<br>
# Tevens werd er door tussentijds print-statements goed inzichtelijk gemaakt wat er precies gebeurt (meeste hiervan zijn ge-outcomment)<br>
# Aan de hand van een YouTube-tutorial heb ik de onderstaande code meegeschreven, later nog zaken als bv. Confusion Matrix toegevoegd.
#
# Tutorial: https://www.youtube.com/watch?v=bns5ELvbzVk&t=86s + https://www.youtube.com/watch?v=ZN6P_GEJ7lk&t=1375s

# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
import numpy as np

from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

import datetime

import random

# Onderstaande heb ik op een later tijdstip toegevoegd om te kijken of dit a. werkte en b. meerwaarde kon hebben.
# https://www.tensorflow.org/tensorboard/tensorboard_in_notebooks
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %% [markdown]
# Onderstaande blok is later toegevoegd om steeds vanuit dezelfde beginsituatie te kunnen vertrekken.

# %%
# The below is necessary for starting:
# Numpy / 
# core Python /  
# TensorFlow backend generated random numbers
# in a well-defined initial state.

np.random.seed(123)

random.seed(123)

tf.random.set_seed(1234)

# For further details, see:
# https://www.tensorflow.org/api_docs/python/tf/random/set_seed

# %%
# Can be used to clear any Tensorboard logs from previous runs
# rm -rf ./data/logs/

# %% [markdown]
# De variabelen zijn met hier met hoofdletters geschreven omdat ze "constanten" zijn.<br>
#
# <strong>Assigning and Declaring Python Constants</strong><br>
# The first and foremost thing to remember while declaring Python Constants is that the constant values should always be declared in capital letters/uppercase.<br>
# The values declared should not be abbreviations of the names, and it has to be declared completely.<br>
# https://www.educba.com/python-constants/

# %%
IMAGE_SIZE = 200
BATCH_SIZE = 32
CHANNELS = 3
EPOCHS = 75

# %% [markdown]
# Inladen van de data (images)

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "../augmented_data/Train",
    seed = 123,
    shuffle = True,
    image_size = (IMAGE_SIZE, IMAGE_SIZE),
    batch_size = BATCH_SIZE
)

# hier wordt de augmented_data set van 4000 (1000 per label) afb. ingeladen
# Out:
# Found 4000 files belonging to 4 classes.

# %% [markdown]
# Ophalen van labels

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Blotch_Apple', 'Normal_Apple', 'Rot_Apple', 'Scab_Apple']

# %%
# len(dataset)
# length is aantal batches van 32 (32 x 125 = 4000)

# %% [markdown]
# Inladen van testset

# %%
testset = tf.keras.preprocessing.image_dataset_from_directory(
    "../augmented_data/Test",
    seed = 123,
    shuffle = True,
    image_size = (IMAGE_SIZE, IMAGE_SIZE),
    batch_size = BATCH_SIZE
)
# Out:
# Found 120 files belonging to 4 classes.

# %%
class_names = testset.class_names
class_names
# Out:
# ['Blotch_Apple', 'Normal_Apple', 'Rot_Apple', 'Scab_Apple']

# %%
# len(testset)

# %% [markdown]
# Voor een visuele inspectie van de afbeeldingen en bijbehorende labels in de data-set

# %%
plt.figure(figsize=(8, 8)) # om dimensies totale afbeelding aan te passen en tekst leesbaar te houden
for image_batch, label_batch in dataset.take(1): # toont at random afbeeldingen uit de dataset
    # print(image_batch.shape)    # batch shape is 32 afb. à 224x224 pixels in RGB
    # print(label_batch.numpy())  # labels van de batch
    # print(image_batch[0].numpy) # numpy array
    # print(image_batch[0].shape) # dimensies van afb. 224x224 pixels in RGB
    for i in range(12):
        ax = plt.subplot(3, 4, i+1)    
        # plt.imshow(image_batch[0].numpy().astype("uint8"))
        # plt.title(class_names[label_batch[0]])
        plt.imshow(image_batch[i].numpy().astype("uint8")) # met [i] wordt de loop doorlopen en 12 afb. getoond, met vaste waarde bv. [0] wordt één afb. 12x getoond
        plt.title(class_names[label_batch[i]])
        plt.axis("off") # om extra informatie (> assen) uit te zetten

# %% [markdown]
# Zo ook voor de testdata

# %%
# plt.figure(figsize=(10, 10)) # om dimensies totale afbeelding aan te passen en tekst leesbaar te houden
# for image_batch, label_batch in testset.take(1): # toont at random afbeeldingen uit de dataset
#     for i in range(12):
#         ax = plt.subplot(3, 4, i+1)    
#         plt.imshow(image_batch[i].numpy().astype("uint8")) 
#         plt.title(class_names[label_batch[i]])
#         plt.axis("off")

# %% [markdown]
# Berekenen hoe de dataset in train- en validation-dataset, en evt. test-dataset opgedeeld kan worden.

# %%
# 80% van de dataset voor training
# train_size = 0.8
# len(dataset)*train_size # (in batches)

# %%
# train_ds = dataset.take(100) # met .take() worden de eerste (x) batches geslecteerd
# len(train_ds)

# %%
# test_ds = dataset.skip() # met .skip() worden er overgeslagen, maar ...
# omdat we een aparte folder voor de test-dataset hebben, kunnen we deze als onderstaand inladen
# test_ds = testset
# len(test_ds) # lengte in batches

# %%
# 20% van de dataset voor validation
# val_size = 0.2
# len(dataset)*val_size

# %%
# val_ds = dataset.skip(100)
# len(val_ds)

# eerste 100 batches voor training, deze slaan we over (.skip) en nemen de laatste 25 voor validation

# %% [markdown]
# Wat bovenstaand berekend is, kunnen we ook als onderstaande functie opschrijven:

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.2, shuffle=True, shuffle_size=10000): # test_split niet, want extra folder met test-afbeeldingen

    assert (train_split + val_split) == 1 
    ds_size = len(ds)
    
    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12) # seed for predictability, same result 
        
    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)
    
    train_ds = ds.take(train_size)
    
    val_ds = ds.skip(train_size).take(val_size)
    # test_ds = ds.skip(train_size).skip(val_size) # als we de test-dataset ook uit dezelfde batch/folder zouden halen
    test_ds = testset
        
    return train_ds, val_ds, test_ds

# %% [markdown]
# Vanuit de functie kunnen de datasets aangemaakt worden.

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)

# %% [markdown]
# Ter controle kunnen onderstaande cellen gerund worden.

# %%
# len(train_ds)

# %%
# len(val_ds)

# %%
# len(test_ds)

# %%
# train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE) # bij CPU én GPU gebruik om afb. te cachen en zo sneller data in te laden.
# val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
# test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %% [markdown]
# <h3><strong>Preprocessing pipeline</strong></h3><br>
# <strong>Resize en rescale</strong> om de afbeeldingen allemaal dezelfde afmetingen te geven en de waarden tussen 0 en 1 te zetten.

# %%
resize_and_rescale = tf.keras.Sequential([
    layers.experimental.preprocessing.Resizing(IMAGE_SIZE,IMAGE_SIZE),
    layers.experimental.preprocessing.Rescaling(1./255)    
])

# %% [markdown]
# <strong>Data augementation</strong> om de afbeeldingen te modificeren:<br>
# <ul>
#     <li>
# horizontaal en verticaal flippen
# </li>
# <li>
# willekeurige rotatie
# </li>
# <li>
# zoom
# </li>
# </ul>

# %%
data_augmentation = tf.keras.Sequential([
    layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
    layers.experimental.preprocessing.RandomRotation(0.2),
    layers.experimental.preprocessing.RandomZoom(0.4),
    layers.experimental.preprocessing.RandomContrast(
    factor=0.5, seed=None, name=None)
])

# %% [markdown]
# Apply data augmentation to train dataset

# %%
train_ds = train_ds.map(
    lambda x, y: (data_augmentation(x, training=True), y)
).prefetch(buffer_size=tf.data.AUTOTUNE)

# %% [markdown]
# Batch normalization om het model sneller en stabieler te maken. Bij Batch normalization wordt

# %%
batch_normalization = tf.keras.layers.BatchNormalization(
    axis=-1,
    momentum=0.99,
    epsilon=0.001,
    center=True,
    scale=True,
    beta_initializer='zeros',
    gamma_initializer='ones',
    moving_mean_initializer='zeros',
    moving_variance_initializer='ones',
    beta_regularizer=None,
    gamma_regularizer=None,
    beta_constraint=None,
    gamma_constraint=None,
)

# minus **kwargs

# %%
input_shape = (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNELS)
n_classes = 4

model = models.Sequential([
    resize_and_rescale,
    data_augmentation,
    layers.Conv2D(32, (3,3), activation='relu', input_shape=input_shape),
    batch_normalization,
    layers.MaxPooling2D((2,2)), 
    # layers.Dropout(0.2), 
    layers.Conv2D(64, (3,3),activation='relu'), # padding='same'
    tf.keras.layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),
    # layers.Dropout(0.2),
    layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),   
    # layers.Dropout(0.2), 
    layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),
    # layers.Dropout(0.2),
    layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),
    # layers.Dropout(0.2),
    layers.Conv2D(256, (3,3), activation='relu'),
    tf.keras.layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),   
    # layers.Dropout(0.2),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(n_classes, activation='softmax')          
])

model.build(input_shape=input_shape)

# %% [markdown]
# Callback voor early stopping. In de praktijk is deze functie bijna niet gebruikt, weinig voorgekomen dat er eerder gestopt moet worden.

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)

# %% [markdown]
# Overzicht van de topologie van het model.

# %%
# model.summary()

# %% [markdown]
# Tensorboard logs

# %%
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# %%
model.compile(
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),   # laatste layer in model gebruikt softmax als activatie
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_ds,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=1,
    validation_data=val_ds,
    callbacks = [tensorboard_callback]
)
# Out:
# Epoch 1/75
# 100/100 [==============================] - 40s 341ms/step - loss: 1.0980 - accuracy: 0.5556 - val_loss: 1.3944 - val_accuracy: 0.4038
# Epoch 2/75
# 100/100 [==============================] - 38s 365ms/step - loss: 0.8994 - accuracy: 0.6297 - val_loss: 1.7621 - val_accuracy: 0.2625
# Epoch 3/75
# 100/100 [==============================] - 46s 435ms/step - loss: 0.8219 - accuracy: 0.6750 - val_loss: 1.2741 - val_accuracy: 0.4663
# Epoch 4/75
# 100/100 [==============================] - 46s 442ms/step - loss: 0.8115 - accuracy: 0.6791 - val_loss: 0.9693 - val_accuracy: 0.5975
# Epoch 5/75
# 100/100 [==============================] - 44s 419ms/step - loss: 0.6737 - accuracy: 0.7344 - val_loss: 0.6026 - val_accuracy: 0.7700
# Epoch 6/75
# 100/100 [==============================] - 43s 407ms/step - loss: 0.7034 - accuracy: 0.7191 - val_loss: 0.4904 - val_accuracy: 0.8062
# Epoch 7/75
# 100/100 [==============================] - 44s 417ms/step - loss: 0.6184 - accuracy: 0.7572 - val_loss: 0.4667 - val_accuracy: 0.8325
# Epoch 8/75
# 100/100 [==============================] - 46s 435ms/step - loss: 0.5735 - accuracy: 0.7753 - val_loss: 0.4774 - val_accuracy: 0.8150
# Epoch 9/75
# 100/100 [==============================] - 43s 399ms/step - loss: 0.5525 - accuracy: 0.7919 - val_loss: 0.4990 - val_accuracy: 0.8037
# Epoch 10/75
# 100/100 [==============================] - 45s 425ms/step - loss: 0.5068 - accuracy: 0.8025 - val_loss: 0.4600 - val_accuracy: 0.8112
# Epoch 11/75
# 100/100 [==============================] - 52s 490ms/step - loss: 0.4820 - accuracy: 0.8172 - val_loss: 0.4407 - val_accuracy: 0.8388
# Epoch 12/75
# 100/100 [==============================] - 42s 397ms/step - loss: 0.4296 - accuracy: 0.8353 - val_loss: 0.3622 - val_accuracy: 0.8675
# Epoch 13/75
# 100/100 [==============================] - 43s 402ms/step - loss: 0.4648 - accuracy: 0.8222 - val_loss: 0.3518 - val_accuracy: 0.8637
# Epoch 14/75
# 100/100 [==============================] - 42s 399ms/step - loss: 0.4064 - accuracy: 0.8500 - val_loss: 0.2626 - val_accuracy: 0.9062
# Epoch 15/75
# 100/100 [==============================] - 43s 404ms/step - loss: 0.4090 - accuracy: 0.8434 - val_loss: 0.2856 - val_accuracy: 0.8788
# Epoch 16/75
# 100/100 [==============================] - 42s 400ms/step - loss: 0.3750 - accuracy: 0.8612 - val_loss: 0.1949 - val_accuracy: 0.9337
# Epoch 17/75
# 100/100 [==============================] - 43s 403ms/step - loss: 0.3543 - accuracy: 0.8603 - val_loss: 0.2601 - val_accuracy: 0.9087
# Epoch 18/75
# 100/100 [==============================] - 45s 428ms/step - loss: 0.3307 - accuracy: 0.8763 - val_loss: 0.1487 - val_accuracy: 0.9438
# Epoch 19/75
# 100/100 [==============================] - 43s 402ms/step - loss: 0.3255 - accuracy: 0.8841 - val_loss: 0.1800 - val_accuracy: 0.9438
# Epoch 20/75
# 100/100 [==============================] - 43s 405ms/step - loss: 0.3386 - accuracy: 0.8775 - val_loss: 0.1704 - val_accuracy: 0.9400
# Epoch 21/75
# 100/100 [==============================] - 43s 403ms/step - loss: 0.3224 - accuracy: 0.8834 - val_loss: 0.3150 - val_accuracy: 0.8913
# Epoch 22/75
# 100/100 [==============================] - 43s 402ms/step - loss: 0.2872 - accuracy: 0.8934 - val_loss: 0.3803 - val_accuracy: 0.8537
# Epoch 23/75
# 100/100 [==============================] - 42s 400ms/step - loss: 0.2781 - accuracy: 0.8972 - val_loss: 0.1436 - val_accuracy: 0.9513
# Epoch 24/75
# 100/100 [==============================] - 42s 400ms/step - loss: 0.2915 - accuracy: 0.8913 - val_loss: 0.1274 - val_accuracy: 0.9538
# Epoch 25/75
# 100/100 [==============================] - 43s 401ms/step - loss: 0.2773 - accuracy: 0.8947 - val_loss: 0.1171 - val_accuracy: 0.9600
# Epoch 26/75
# 100/100 [==============================] - 42s 400ms/step - loss: 0.2889 - accuracy: 0.8978 - val_loss: 0.1159 - val_accuracy: 0.9563
# Epoch 27/75
# 100/100 [==============================] - 47s 444ms/step - loss: 0.2522 - accuracy: 0.9081 - val_loss: 0.1378 - val_accuracy: 0.9575
# Epoch 28/75
# 100/100 [==============================] - 41s 383ms/step - loss: 0.2257 - accuracy: 0.9197 - val_loss: 0.0768 - val_accuracy: 0.9725
# Epoch 29/75
# 100/100 [==============================] - 41s 390ms/step - loss: 0.2347 - accuracy: 0.9169 - val_loss: 0.1074 - val_accuracy: 0.9613
# Epoch 30/75
# 100/100 [==============================] - 42s 393ms/step - loss: 0.2160 - accuracy: 0.9266 - val_loss: 0.0536 - val_accuracy: 0.9850
# Epoch 31/75
# 100/100 [==============================] - 43s 412ms/step - loss: 0.2108 - accuracy: 0.9222 - val_loss: 0.1177 - val_accuracy: 0.9588
# Epoch 32/75
# 100/100 [==============================] - 43s 410ms/step - loss: 0.2167 - accuracy: 0.9216 - val_loss: 0.0872 - val_accuracy: 0.9725
# Epoch 33/75
# 100/100 [==============================] - 42s 394ms/step - loss: 0.2005 - accuracy: 0.9231 - val_loss: 0.1248 - val_accuracy: 0.9550
# Epoch 34/75
# 100/100 [==============================] - 42s 397ms/step - loss: 0.2082 - accuracy: 0.9206 - val_loss: 0.0877 - val_accuracy: 0.9688
# Epoch 35/75
# 100/100 [==============================] - 42s 397ms/step - loss: 0.1660 - accuracy: 0.9438 - val_loss: 0.0783 - val_accuracy: 0.9688
# Epoch 36/75
# 100/100 [==============================] - 43s 403ms/step - loss: 0.1573 - accuracy: 0.9428 - val_loss: 0.0496 - val_accuracy: 0.9887
# Epoch 37/75
# 100/100 [==============================] - 43s 404ms/step - loss: 0.1960 - accuracy: 0.9322 - val_loss: 0.0511 - val_accuracy: 0.9850
# Epoch 38/75
# 100/100 [==============================] - 42s 401ms/step - loss: 0.1667 - accuracy: 0.9425 - val_loss: 0.0542 - val_accuracy: 0.9862
# Epoch 39/75
# 100/100 [==============================] - 51s 484ms/step - loss: 0.1785 - accuracy: 0.9344 - val_loss: 0.0851 - val_accuracy: 0.9725
# Epoch 40/75
# 100/100 [==============================] - 45s 414ms/step - loss: 0.1514 - accuracy: 0.9494 - val_loss: 0.0805 - val_accuracy: 0.9650
# Epoch 41/75
# 100/100 [==============================] - 48s 452ms/step - loss: 0.1523 - accuracy: 0.9456 - val_loss: 0.4210 - val_accuracy: 0.8475
# Epoch 42/75
# 100/100 [==============================] - 47s 447ms/step - loss: 0.1847 - accuracy: 0.9306 - val_loss: 0.0745 - val_accuracy: 0.9725
# Epoch 43/75
# 100/100 [==============================] - 45s 424ms/step - loss: 0.1829 - accuracy: 0.9384 - val_loss: 0.0419 - val_accuracy: 0.9837
# Epoch 44/75
# 100/100 [==============================] - 44s 416ms/step - loss: 0.1589 - accuracy: 0.9450 - val_loss: 0.1226 - val_accuracy: 0.9525
# Epoch 45/75
# 100/100 [==============================] - 42s 397ms/step - loss: 0.1821 - accuracy: 0.9312 - val_loss: 0.0507 - val_accuracy: 0.9850
# Epoch 46/75
# 100/100 [==============================] - 42s 397ms/step - loss: 0.1572 - accuracy: 0.9453 - val_loss: 0.0981 - val_accuracy: 0.9638
# Epoch 47/75
# 100/100 [==============================] - 42s 398ms/step - loss: 0.1581 - accuracy: 0.9441 - val_loss: 0.0454 - val_accuracy: 0.9837
# Epoch 48/75
# 100/100 [==============================] - 42s 398ms/step - loss: 0.1453 - accuracy: 0.9466 - val_loss: 0.0987 - val_accuracy: 0.9663
# Epoch 49/75
# 100/100 [==============================] - 45s 421ms/step - loss: 0.1307 - accuracy: 0.9566 - val_loss: 0.0256 - val_accuracy: 0.9925
# Epoch 50/75
# 100/100 [==============================] - 42s 397ms/step - loss: 0.1511 - accuracy: 0.9447 - val_loss: 0.0630 - val_accuracy: 0.9775
# Epoch 51/75
# 100/100 [==============================] - 44s 413ms/step - loss: 0.1378 - accuracy: 0.9525 - val_loss: 0.0365 - val_accuracy: 0.9887
# Epoch 52/75
# 100/100 [==============================] - 43s 411ms/step - loss: 0.1302 - accuracy: 0.9538 - val_loss: 0.0695 - val_accuracy: 0.9750
# Epoch 53/75
# 100/100 [==============================] - 44s 411ms/step - loss: 0.1433 - accuracy: 0.9478 - val_loss: 0.0540 - val_accuracy: 0.9800
# Epoch 54/75
# 100/100 [==============================] - 42s 395ms/step - loss: 0.1364 - accuracy: 0.9519 - val_loss: 0.0807 - val_accuracy: 0.9700
# Epoch 55/75
# 100/100 [==============================] - 45s 430ms/step - loss: 0.1246 - accuracy: 0.9566 - val_loss: 0.0427 - val_accuracy: 0.9900
# Epoch 56/75
# 100/100 [==============================] - 44s 410ms/step - loss: 0.1115 - accuracy: 0.9588 - val_loss: 0.0509 - val_accuracy: 0.9837
# Epoch 57/75
# 100/100 [==============================] - 43s 403ms/step - loss: 0.1197 - accuracy: 0.9588 - val_loss: 0.0567 - val_accuracy: 0.9787
# Epoch 58/75
# 100/100 [==============================] - 44s 413ms/step - loss: 0.1065 - accuracy: 0.9631 - val_loss: 0.0265 - val_accuracy: 0.9887
# Epoch 59/75
# 100/100 [==============================] - 52s 489ms/step - loss: 0.0913 - accuracy: 0.9659 - val_loss: 0.0233 - val_accuracy: 0.9937
# Epoch 60/75
# 100/100 [==============================] - 53s 502ms/step - loss: 0.1412 - accuracy: 0.9503 - val_loss: 0.0583 - val_accuracy: 0.9812
# Epoch 61/75
# 100/100 [==============================] - 46s 437ms/step - loss: 0.1375 - accuracy: 0.9475 - val_loss: 0.0256 - val_accuracy: 0.9937
# Epoch 62/75
# 100/100 [==============================] - 43s 407ms/step - loss: 0.0857 - accuracy: 0.9712 - val_loss: 0.0390 - val_accuracy: 0.9875
# Epoch 63/75
# 100/100 [==============================] - 44s 413ms/step - loss: 0.1134 - accuracy: 0.9606 - val_loss: 0.0355 - val_accuracy: 0.9875
# Epoch 64/75
# 100/100 [==============================] - 44s 409ms/step - loss: 0.0996 - accuracy: 0.9678 - val_loss: 0.0265 - val_accuracy: 0.9862
# Epoch 65/75
# 100/100 [==============================] - 44s 414ms/step - loss: 0.1043 - accuracy: 0.9650 - val_loss: 0.0327 - val_accuracy: 0.9887
# Epoch 66/75
# 100/100 [==============================] - 46s 422ms/step - loss: 0.1103 - accuracy: 0.9638 - val_loss: 0.0209 - val_accuracy: 0.9925
# Epoch 67/75
# 100/100 [==============================] - 46s 423ms/step - loss: 0.1102 - accuracy: 0.9678 - val_loss: 0.0292 - val_accuracy: 0.9887
# Epoch 68/75
# 100/100 [==============================] - 40s 374ms/step - loss: 0.1041 - accuracy: 0.9631 - val_loss: 0.0137 - val_accuracy: 0.9987
# Epoch 69/75
# 100/100 [==============================] - 40s 373ms/step - loss: 0.1255 - accuracy: 0.9547 - val_loss: 0.0639 - val_accuracy: 0.9787
# Epoch 70/75
# 100/100 [==============================] - 39s 371ms/step - loss: 0.1042 - accuracy: 0.9600 - val_loss: 0.0937 - val_accuracy: 0.9663
# Epoch 71/75
# 100/100 [==============================] - 40s 372ms/step - loss: 0.1021 - accuracy: 0.9641 - val_loss: 0.0281 - val_accuracy: 0.9887
# Epoch 72/75
# 100/100 [==============================] - 40s 374ms/step - loss: 0.1150 - accuracy: 0.9613 - val_loss: 0.3048 - val_accuracy: 0.8950
# Epoch 73/75
# 100/100 [==============================] - 46s 431ms/step - loss: 0.1283 - accuracy: 0.9522 - val_loss: 0.0355 - val_accuracy: 0.9887
# Epoch 74/75
# 100/100 [==============================] - 45s 422ms/step - loss: 0.0977 - accuracy: 0.9644 - val_loss: 0.0206 - val_accuracy: 0.9900
# Epoch 75/75
# 100/100 [==============================] - 49s 458ms/step - loss: 0.1188 - accuracy: 0.9606 - val_loss: 0.0159 - val_accuracy: 0.9962

# %%
scores = model.evaluate(test_ds)
# Out:
# 4/4 [==============================] - 1s 178ms/step - loss: 1.7696 - accuracy: 0.6833

# %%
# scores

# %%
# history

# %%
# history.params

# %%
# history.history.keys()

# %%
# len(history.history['accuracy'])

# %%
# type(history.history['loss'])
# len(history.history['loss'])

# %%
# history.history['loss'][:5]# show loss for first 5 epochs

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize=(8, 4))

plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')

plt.show()

# %%
for images_batch, labels_batch in test_ds.take(1):
    
    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()
    
    print("First image to predict")
    plt.imshow(first_image)
    plt.axis("off")
    print("First image's actual label:", class_names[first_label])
    
    batch_prediction = model.predict(images_batch)
    print("Predicted label:", class_names[np.argmax(batch_prediction[0])])
    # print(batch_prediction[0]) # input for np.argmax() above
# Out:
# First image to predict
# First image's actual label: Blotch_Apple
# Predicted label: Blotch_Apple

# %% [markdown]
# Met de predict functie kunnen we het <i>eigenlijke</i> en <i>voorspelde</i> label in een overzicht van afbeeldingen tonen en<br>
# aangeven met welke <i>zekerheid</i> de uitspraak gedaan kan worden.<br>
#
# Met <i>shuffle = True</i> bij het inladen van de testdata wordt er slechts vanuit één label afbeeldingen ingeladen.

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images_batch[i])
    img_array = tf.expand_dims(img_array, 0) # Create a batch
    
    predictions = model.predict(img_array)
       
    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i+1)
        
        plt.imshow(images[i].numpy().astype("uint8"))
        
        predicted_class, confidence = predict(model, images[i].numpy()) 
        actual_class = class_names[labels[i]]
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        
        plt.axis("off")

# %% [markdown]
# Met onderstaande code wordt er voor elke run een nieuwe (genummerde) folder aangemaakt waarin het model opgeslagen wordt.

# %%
import os

model_version=max([int(i) for i in os.listdir("../models") + [0]])+1
model.save(f"../models/{model_version}") # check ValueError: invalid literal for int() with base 10: '.gitkeep' <<<
# Out:
# INFO:tensorflow:Assets written to: ../models/34\assets

# %% [markdown]
# Model opslaan kan ook als onderstaand, maar de .h5-variant is deprecated:<br>
#
# There are two formats you can use to save an entire model to disk: the <strong>TensorFlow SavedModel </strong>format, and the older Keras H5 format. The recommended format is SavedModel. It is the default when you use model.save(). > https://www.tensorflow.org/guide/keras/ save_and_serialize <. Hence the method above is preferred.

# %%
# model.save("..models/../apples.h5")

# %%
model.predict(test_ds)
# Out:
# array([[9.98758078e-01, 1.67553900e-08, 7.09932589e-04, 5.31971105e-04],
#        [1.59665674e-03, 7.65655041e-02, 7.49190585e-05, 9.21762884e-01],
#        [1.84819456e-07, 3.11212239e-06, 3.52867028e-06, 9.99993086e-01],
#        [8.05735812e-02, 1.35962591e-05, 9.19357359e-01, 5.54579528e-05],
#        [2.48265488e-11, 5.47164751e-14, 1.00000000e+00, 1.09390710e-08],
#        [1.76539216e-02, 1.44557474e-04, 4.72455084e-01, 5.09746492e-01],
#        [4.20014476e-05, 9.93151307e-01, 6.80463715e-03, 2.05433139e-06],
#        [3.53036249e-08, 3.87239290e-08, 9.99987245e-01, 1.26077139e-05],
#        [1.09284469e-04, 1.18694148e-08, 9.99888420e-01, 2.21855635e-06],
#        [1.12048452e-04, 3.18615894e-05, 9.99831557e-01, 2.45995107e-05],
#        [3.09260940e-04, 9.99599040e-01, 5.93144023e-06, 8.57702180e-05],
#        [1.75493471e-02, 4.15931077e-04, 1.70713337e-03, 9.80327547e-01],
#        [1.15210014e-06, 1.31974778e-11, 9.99907970e-01, 9.08771399e-05],
#        [5.28846504e-05, 1.99616732e-08, 6.01760490e-08, 9.99946952e-01],
#        [5.67848474e-07, 2.33963598e-02, 9.76597786e-01, 5.28957162e-06],
#        [2.62896610e-05, 9.17833809e-09, 9.99973655e-01, 5.72115830e-08],
#        [9.08991478e-06, 5.65515256e-05, 7.77112087e-04, 9.99157310e-01],
#        [1.65252679e-03, 9.67547834e-01, 2.71119713e-03, 2.80884616e-02],
#        [1.55496434e-06, 2.09605135e-03, 9.97899175e-01, 3.25401402e-06],
#        [9.99748290e-01, 2.99328094e-05, 4.02344824e-08, 2.21767870e-04],
#        [5.25411849e-07, 1.30895729e-04, 9.99867558e-01, 9.20967295e-07],
#        [9.89628196e-01, 2.92563753e-04, 1.58073124e-03, 8.49849172e-03],
#        [2.37938552e-03, 9.58626866e-01, 3.72309275e-02, 1.76287931e-03],
#        [4.07646835e-01, 5.53384837e-07, 1.62846997e-01, 4.29505646e-01],
#        [5.33650219e-02, 9.18715477e-01, 2.21412946e-02, 5.77828474e-03],
#        [2.42530759e-02, 5.70625603e-01, 3.07798207e-01, 9.73230675e-02],
#        [7.04849572e-06, 1.37920196e-11, 2.90442983e-07, 9.99992728e-01],
#        [2.60406751e-02, 1.37193510e-05, 9.73945618e-01, 3.46179228e-08],
#        [3.41484764e-07, 1.04882103e-08, 9.89483654e-01, 1.05160307e-02],
#        [7.48873297e-10, 5.48658500e-05, 9.99938846e-01, 6.36586992e-06],
#        [5.57353022e-04, 2.05920846e-03, 2.60456035e-09, 9.97383416e-01],
#        [6.43093288e-01, 1.59432795e-06, 7.41886301e-03, 3.49486262e-01],
#        [8.37893367e-06, 5.94896243e-14, 3.18033162e-05, 9.99959826e-01],
#        [1.20565726e-03, 3.91136011e-04, 1.94879954e-06, 9.98401344e-01],
#        [2.50579417e-03, 9.56938348e-12, 1.01059370e-01, 8.96434784e-01],
#        [8.37484695e-05, 6.35593057e-01, 7.93647246e-08, 3.64323169e-01],
#        [1.64950296e-01, 3.88395160e-01, 9.21845494e-04, 4.45732623e-01],
#        [1.49661399e-04, 3.32252275e-05, 9.99806821e-01, 1.03171560e-05],
#        [4.15613249e-05, 3.78254731e-06, 2.13390308e-06, 9.99952555e-01],
#        [9.97628748e-01, 1.91894815e-05, 1.98055250e-06, 2.35019159e-03],
#        [1.76289232e-05, 9.87075984e-01, 1.28927445e-02, 1.36145745e-05],
#        [1.61837682e-01, 5.17850965e-02, 2.35154018e-01, 5.51223278e-01],
#        [2.60856950e-06, 1.29527550e-07, 1.47047380e-04, 9.99850154e-01],
#        [4.23140678e-04, 8.50635621e-12, 3.73329527e-08, 9.99576867e-01],
#        [9.53859508e-01, 4.99013346e-04, 1.72462478e-05, 4.56241593e-02],
#        [1.22129178e-08, 6.34961354e-04, 9.99340475e-01, 2.45078081e-05],
#        [2.90115906e-07, 6.75392897e-08, 9.99510765e-01, 4.88915888e-04],
#        [1.66149357e-06, 1.84383953e-05, 9.99969482e-01, 1.04121618e-05],
#        [5.24608083e-02, 9.79430508e-04, 2.00481653e-01, 7.46078134e-01],
#        [2.81192339e-03, 3.20984909e-05, 6.89953612e-03, 9.90256429e-01],
#        [5.34376577e-02, 3.53824325e-05, 4.63656619e-07, 9.46526468e-01],
#        [6.86623668e-03, 3.74146771e-06, 5.24707830e-05, 9.93077636e-01],
#        [4.21633786e-08, 3.13179444e-05, 9.99598086e-01, 3.70557187e-04],
#        [1.16099507e-01, 5.77503961e-05, 8.62827837e-01, 2.10149400e-02],
#        [5.76244891e-01, 1.36435255e-01, 2.39616960e-01, 4.77028377e-02],
#        [1.66598195e-03, 2.33366247e-02, 1.23972058e-01, 8.51025343e-01],
#        [1.10279694e-02, 4.57693735e-04, 5.48539902e-06, 9.88508761e-01],
#        [2.09716156e-08, 2.32868516e-08, 3.40571290e-07, 9.99999642e-01],
#        [6.24949932e-01, 8.76970531e-04, 2.05829216e-04, 3.73967320e-01],
#        [2.95142084e-03, 6.69868641e-08, 3.77185679e-05, 9.97010827e-01],
#        [5.73163028e-08, 7.02176511e-11, 9.99875903e-01, 1.24127793e-04],
#        [3.83391604e-02, 9.59816813e-01, 1.67923851e-03, 1.64696874e-04],
#        [1.07172738e-04, 4.20219963e-04, 9.96022403e-01, 3.45014897e-03],
#        [8.19189008e-03, 3.16091865e-01, 9.89965629e-04, 6.74726248e-01],
#        [9.98858809e-01, 2.31313220e-06, 7.77346140e-05, 1.06124231e-03],
#        [3.68351393e-05, 9.98016000e-01, 1.94587070e-03, 1.28445697e-06],
#        [2.01805160e-05, 1.62227341e-04, 9.99783576e-01, 3.40385959e-05],
#        [2.44018157e-08, 3.28399281e-08, 1.00000000e+00, 4.62083989e-08],
#        [1.45895220e-03, 9.74059224e-01, 2.22729109e-02, 2.20882776e-03],
#        [1.31532252e-01, 4.74711601e-03, 4.18990203e-06, 8.63716424e-01],
#        [1.64449975e-01, 5.25055034e-03, 6.35487493e-04, 8.29663992e-01],
#        [6.43499778e-04, 4.41604556e-04, 9.98913407e-01, 1.59088336e-06],
#        [5.30910768e-07, 7.14645876e-06, 4.51628694e-07, 9.99991894e-01],
#        [4.87514198e-01, 1.30500069e-07, 4.45232838e-01, 6.72528967e-02],
#        [2.11063707e-06, 3.69966077e-03, 9.96294081e-01, 4.17043384e-06],
#        [4.99226809e-01, 4.83247350e-05, 2.65060186e-01, 2.35664666e-01],
#        [8.88714671e-01, 5.41030374e-07, 1.09833904e-01, 1.45091617e-03],
#        [6.01173053e-03, 9.17126672e-05, 8.20897520e-01, 1.72999069e-01],
#        [6.19274974e-01, 1.75336272e-01, 1.46898979e-04, 2.05241874e-01],
#        [1.23183606e-02, 2.51528283e-04, 9.87194002e-01, 2.36083535e-04],
#        [3.97169404e-02, 1.25914166e-11, 9.34952736e-01, 2.53303722e-02],
#        [8.95131379e-02, 7.94401512e-06, 5.68312034e-02, 8.53647709e-01],
#        [2.56934109e-05, 3.49115015e-10, 9.99736607e-01, 2.37592903e-04],
#        [7.09778130e-01, 1.03088049e-03, 2.29886360e-02, 2.66202271e-01],
#        [9.40034688e-01, 3.14744199e-07, 3.28770056e-02, 2.70879678e-02],
#        [8.29584241e-01, 2.88264011e-03, 4.86986749e-02, 1.18834428e-01],
#        [2.44926661e-02, 1.56261027e-03, 7.17314265e-07, 9.73944008e-01],
#        [8.30283612e-02, 8.84451531e-03, 8.77337694e-01, 3.07894088e-02],
#        [4.79576386e-07, 1.93537362e-05, 9.96418595e-01, 3.56162456e-03],
#        [1.20711385e-03, 6.58605932e-05, 5.98708692e-04, 9.98128235e-01],
#        [6.38380587e-01, 1.91686559e-04, 2.42817700e-01, 1.18610024e-01],
#        [4.13269208e-06, 2.90234141e-07, 2.98326413e-05, 9.99965787e-01],
#        [2.81686371e-05, 9.95234668e-01, 2.50759585e-05, 4.71214997e-03],
#        [1.54616376e-02, 7.57812917e-01, 2.09821880e-01, 1.69034693e-02],
#        [1.72236958e-03, 3.53308466e-10, 4.10815589e-02, 9.57196057e-01],
#        [6.05161011e-04, 2.19390813e-06, 1.76822860e-03, 9.97624457e-01],
#        [9.99978304e-01, 9.33707554e-07, 1.03781156e-06, 1.97493955e-05],
#        [5.58697820e-07, 8.31991565e-05, 9.99915481e-01, 7.14766031e-07],
#        [3.54612644e-06, 7.73462467e-03, 9.91956115e-01, 3.05695517e-04],
#        [9.31911018e-06, 7.32191938e-06, 2.12888040e-06, 9.99981165e-01],
#        [2.12900737e-08, 1.66324421e-09, 9.99926448e-01, 7.35363428e-05],
#        [2.46709416e-04, 3.78361528e-06, 1.95743635e-08, 9.99749482e-01],
#        [6.53816038e-04, 8.26882184e-01, 1.71888113e-01, 5.75878017e-04],
#        [9.99857903e-01, 1.84405749e-07, 6.25852626e-05, 7.92452047e-05],
#        [1.95300300e-03, 3.41113065e-07, 9.25150793e-03, 9.88795042e-01],
#        [6.95343673e-01, 1.38222022e-04, 9.39364210e-02, 2.10581660e-01],
#        [4.75920349e-01, 7.49521423e-05, 7.54257813e-02, 4.48578894e-01],
#        [5.51176527e-07, 1.33539579e-04, 9.99864936e-01, 9.95934442e-07],
#        [1.92137306e-09, 1.88380454e-05, 9.99712884e-01, 2.68284610e-04],
#        [1.50088817e-04, 5.44053137e-06, 1.62091567e-07, 9.99844313e-01],
#        [5.21554875e-06, 2.15372525e-10, 9.99992132e-01, 2.56832527e-06],
#        [1.05290612e-08, 8.84201015e-08, 9.99888062e-01, 1.11815454e-04],
#        [2.62895846e-05, 9.17835496e-09, 9.99973655e-01, 5.72115830e-08],
#        [2.40752733e-08, 6.62007233e-06, 9.97903466e-01, 2.08986667e-03],
#        [9.99405980e-01, 2.16346103e-04, 1.85632859e-06, 3.75857810e-04],
#        [4.90253846e-08, 7.17239175e-07, 3.66880866e-11, 9.99999285e-01],
#        [9.93803376e-04, 2.91688583e-11, 1.29406053e-05, 9.98993218e-01],
#        [9.99987245e-01, 2.10329654e-06, 5.13899477e-06, 5.45855437e-06],
#        [3.96029465e-02, 3.80191863e-01, 4.00365025e-01, 1.79840177e-01],
#        [4.72575090e-09, 9.99999046e-01, 9.84162057e-07, 1.62923605e-10]],
#       dtype=float32)

# %% [markdown]
# Deze confusion matrix met standaard test_ds geeft onbetrouwbare resultaten,<br>
# vandaar dat ik hier onder een nieuwe versie geïmplementeerd heb.

# %%
# predictionBatch = model.predict(test_ds)
# predictionEnhanced = tf.argmax(predictionBatch, axis=-1)
# actualCategories = tf.concat([y for x, y in test_ds], axis=0)

# confusionMatrix = metrics.confusion_matrix(actualCategories, predictionEnhanced)

# cmDisplay = metrics.ConfusionMatrixDisplay(confusion_matrix = confusionMatrix, display_labels = ["Blotch_Apple", "Normal_Apple", "Rot_Apple", "Scab_Apple"])

# cmDisplay.plot()

# plt.show()

# %% [markdown]
# Bij onderstaande "nieuwe" Confusion Matrix laden we de test dataset in met <i>shuffle=False</i>.<br>
# Dit zorgt er enerzijds voor dat de matrix bij opnieuw runnen<br>
# (zonder het gehele model opnieuw te trainen) steeds dezelfde waarden toont,<br>
# daarnaast zijn het aantal goed voorspelde labels (True == Predicted) juist weer,<br>
# komt overeen met percentage uit test validation.

# %%
test_ds = tf.keras.utils.image_dataset_from_directory(
      "../augmented_data/Test",
      shuffle=False,
      image_size=(IMAGE_SIZE, IMAGE_SIZE),
      batch_size = BATCH_SIZE 
      )

test_label = test_ds.class_names

print(test_label)


batchPredictions = model.predict(test_ds)

predicted_categories = tf.argmax(batchPredictions, axis=1)

true_categories = tf.concat([y for x, y in test_ds], axis=0)

result_confusion_matrix = confusion_matrix(true_categories, predicted_categories)

cm_display = ConfusionMatrixDisplay(confusion_matrix = result_confusion_matrix, display_labels = ["Blotch_Apple", "Normal_Apple", "Rot_Apple", "Scab_Apple"])

cm_display.plot()
plt.show()
# Out:
# Found 120 files belonging to 4 classes.
# ['Blotch_Apple', 'Normal_Apple', 'Rot_Apple', 'Scab_Apple']

# %% [markdown]
# Tensorboard werkt en logt resultaten. Heb dit, voor nu, verder niet uitgediept of gebruikt om de resultaten te analyseren.

# %%
# %tensorboard --logdir logs/fit
# Out:
# Reusing TensorBoard on port 6006 (pid 16904), started 13 days, 1:25:03 ago. (Use '!kill 16904' to kill it.)
#       <iframe id="tensorboard-frame-443cdef36840ff07" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-443cdef36840ff07");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
